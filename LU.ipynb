# %% [markdown]
# # ---ARRAYS---

# %%
import numpy

# %%
import numpy as np

arr = np.array([1,2,3,4])

print(arr)
# Out:
# [1 2 3 4]

# %% [markdown]
# # ---ARRAY SORTING---

# %%
arr1 = np.array([[[5,6], [7,8], [1.2],[3,4]]])
print(arr1.ndim)
# Out:
# 3

# %%
print(np.sort(arr1))
# Out:
# [[[1 2]
#   [3 4]
#   [5 6]
#   [7 8]]]

# %% [markdown]
# # ---ARRAY SEARCHING---

# %%
arr2 = np.array([[[12,15],[14,16],[18,20],[21,23]]])
z = np.where(arr2==18)
print (z)
print(arr2.ndim)
# Out:
# (array([0]), array([2]), array([0]))
# 3
